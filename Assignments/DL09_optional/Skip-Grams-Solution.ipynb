# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6554 0.2107 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6190 0.2012 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4765 0.2014 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5622 0.2016 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5240 0.2027 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5502 0.2023 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5688 0.2077 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5336 0.2043 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4486 0.2101 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4146 0.2028 sec/batch
# Nearest to for: oiling, batter, bradycardia, logarithms, voluminous, syngman, woodward, lemelson,
# Nearest to nine: frustrating, spaces, disambiguation, muse, meaty, westport, scoreless, salvius,
# Nearest to years: estaing, having, sunnah, ibf, sinking, gee, hawar, remake,
# Nearest to than: hibernation, covers, rumsfeld, mornings, ty, spanning, marxist, panspermia,
# Nearest to other: tenets, hermetic, storyteller, reversibly, shire, excitatory, vukovar, sullivan,
# Nearest to so: martyrs, oxidising, conciliator, figurehead, avoids, donoghue, suspect, classicist,
# Nearest to and: deluxe, across, friendship, vogel, filled, paco, maintainer, tz,
# Nearest to at: sanity, it, georgi, insulating, nagy, by, apa, merry,
# Nearest to frac: dorians, yau, gant, zapatistas, burying, loya, laughton, suites,
# Nearest to placed: superfamilies, printer, cloth, saadia, cartels, bamiyan, acacia, rochester,
# Nearest to cost: antillean, turnout, indulgence, sills, appliance, hedeby, proposing, chairs,
# Nearest to writers: syphilis, guessed, sonorities, interregnum, nosair, dubai, sweethearts, algeciras,
# Nearest to test: seis, hardens, perpetrated, serge, ata, guesswork, carotid, customizing,
# Nearest to animals: subshell, tarim, predetermined, hardin, mama, drawback, mitral, exemplary,
# Nearest to joseph: dhimmi, zout, morphologically, silhouettes, amphiphilic, bcd, workload, specificities,
# Nearest to construction: spherically, ecma, ilyich, monogatari, plasmids, quadi, elphame, yolande,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4896 0.2077 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3882 0.2011 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3360 0.2011 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2223 0.2016 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1790 0.2008 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1718 0.2018 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1141 0.2020 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0616 0.2030 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0025 0.2056 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9618 0.2036 sec/batch
# Nearest to for: logarithms, oiling, requested, encoded, independently, team, botanical, voluminous,
# Nearest to nine: disambiguation, spaces, frustrating, muse, square, westport, international, heart,
# Nearest to years: having, gee, her, estaing, television, remake, sunnah, arguments,
# Nearest to than: hibernation, covers, smallest, threat, rumsfeld, marxist, though, spanning,
# Nearest to other: tenets, reversibly, data, powering, confused, set, absence, sullivan,
# Nearest to so: avoids, suspect, martyrs, took, imposed, between, circular, refuse,
# Nearest to and: across, translated, filled, friendship, non, deluxe, technologies, animal,
# Nearest to at: sanity, it, companies, merry, georgi, employs, insulating, health,
# Nearest to frac: successful, suites, dorians, dynamic, burying, get, animation, gant,
# Nearest to placed: superfamilies, printer, cloth, just, part, agriculture, rochester, habitation,
# Nearest to cost: appliance, converges, antillean, chairs, proposing, turnout, sills, pleasures,
# Nearest to writers: syphilis, guessed, viciously, income, sweethearts, counted, nosair, universalist,
# Nearest to test: hardens, seis, largely, perpetrated, serge, ask, savior, std,
# Nearest to animals: predetermined, skull, partner, stage, subshell, exterior, tarim, hardin,
# Nearest to joseph: dhimmi, morphologically, treating, concentrate, sp, workload, reprint, amphiphilic,
# Nearest to construction: spherically, run, graphs, reality, likely, ecma, monogatari, sixth,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9392 0.2085 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9022 0.2042 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8676 0.2059 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8373 0.2090 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8258 0.2054 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8183 0.2100 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7876 0.2123 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7786 0.2099 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7874 0.2033 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7924 0.2027 sec/batch
# Nearest to for: voluminous, logarithms, oiling, requested, encoded, woodward, mr, rhyme,
# Nearest to nine: frustrating, spaces, westport, disambiguation, muse, serviceable, international, meaty,
# Nearest to years: gee, usd, having, sunnah, estaing, specialised, hawar, arguments,
# Nearest to than: hibernation, covers, threat, spanning, rumsfeld, smallest, polling, marxist,
# Nearest to other: tenets, hermetic, shire, powering, influences, reversibly, ninlil, add,
# Nearest to so: suspect, avoids, martyrs, refuse, experiencing, imposed, figurehead, bennett,
# Nearest to and: across, translated, mcgraw, filled, friendship, incomes, remainder, deluxe,
# Nearest to at: sanity, merry, nagy, it, companies, swimmer, insulating, senator,
# Nearest to frac: dynamic, suites, burying, animation, transduction, successful, dorians, adequately,
# Nearest to placed: printer, cloth, superfamilies, just, agriculture, part, rochester, rates,
# Nearest to cost: turnout, indulgence, appliance, antillean, converges, chairs, proposing, pleasures,
# Nearest to writers: syphilis, guessed, viciously, algeciras, interregnum, universalist, sweethearts, communiqu,
# Nearest to test: hardens, perpetrated, seis, serge, largely, ask, seo, guesswork,
# Nearest to animals: predetermined, stage, exterior, skull, cheat, exemplary, partner, tarim,
# Nearest to joseph: morphologically, dhimmi, concentrate, reprint, treating, workload, progresses, sp,
# Nearest to construction: spherically, ecma, reality, graphs, monogatari, run, metaphors, sixth,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7724 0.2046 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7718 0.2078 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7253 0.2039 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7110 0.2032 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7360 0.2069 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7118 0.2030 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7281 0.2088 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7171 0.2032 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7085 0.2026 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6684 0.2028 sec/batch
# Nearest to for: voluminous, oiling, woodward, logarithms, requested, dropouts, rhyme, outdoors,
# Nearest to nine: westport, dramatist, jr, frustrating, four, muse, zero, recipient,
# Nearest to years: gee, sunnah, usd, having, ppp, specialised, melanesia, venetian,
# Nearest to than: hibernation, covers, spanning, polling, threat, rumsfeld, smallest, relay,
# Nearest to other: tenets, hermetic, powering, ninlil, unwillingness, shire, add, reversibly,
# Nearest to so: avoids, oxidising, martyrs, suspect, figurehead, refuse, classicist, experiencing,
# Nearest to and: across, mcgraw, decades, deluxe, friendship, filled, translated, polarization,
# Nearest to at: sanity, nagy, swimmer, merry, disbanded, it, centralist, insulating,
# Nearest to frac: dynamic, transduction, burying, coughing, adequately, suites, get, dorians,
# Nearest to placed: superfamilies, printer, cloth, agriculture, just, cartels, saadia, rochester,
# Nearest to cost: indulgence, turnout, sills, antillean, appliance, converges, pleasures, hedeby,
# Nearest to writers: syphilis, guessed, universalist, sweethearts, interregnum, viciously, algeciras, communiqu,
# Nearest to test: perpetrated, seis, hardens, serge, seo, ask, std, ata,
# Nearest to animals: predetermined, exemplary, stage, drawback, hardin, tarim, subshell, exterior,
# Nearest to joseph: reprint, william, morphologically, greenlanders, concentrate, narcissus, dhimmi, treating,
# Nearest to construction: spherically, ecma, usaid, monogatari, ilyich, riders, nigh, run,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6617 0.2080 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6592 0.2077 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6217 0.2126 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6376 0.2092 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6181 0.2062 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6121 0.2034 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6154 0.1514 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5488 0.2127 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5076 0.2128 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5097 0.2046 sec/batch
# Nearest to for: voluminous, oiling, filtered, logarithms, woodward, dropouts, requested, portman,
# Nearest to nine: dramatist, jr, four, recipient, westport, frustrating, zero, three,
# Nearest to years: gee, sunnah, usd, ppp, venetian, conglomeration, drafted, having,
# Nearest to than: hibernation, covers, spanning, polling, rumsfeld, relay, take, smallest,
# Nearest to other: tenets, hermetic, powering, ninlil, unwillingness, influences, hypostatic, add,
# Nearest to so: oxidising, avoids, classmates, suspect, you, figurehead, experiencing, martyrs,
# Nearest to and: across, mcgraw, decades, translated, friendship, deluxe, groves, filled,
# Nearest to at: sanity, centralist, swimmer, merry, gnaeus, nagy, it, silk,
# Nearest to frac: dynamic, transduction, adequately, coughing, viruses, zapatistas, suites, burying,
# Nearest to placed: superfamilies, printer, cloth, just, agriculture, hilly, damages, saadia,
# Nearest to cost: indulgence, sills, antillean, turnout, appliance, converges, pleasures, chairs,
# Nearest to writers: syphilis, sweethearts, guessed, universalist, interregnum, algeciras, viciously, nosair,
# Nearest to test: perpetrated, serge, hardens, seis, guesswork, flora, seo, std,
# Nearest to animals: predetermined, subshell, hardin, tarim, drawback, stage, skull, exemplary,
# Nearest to joseph: william, reprint, greenlanders, watson, publisher, american, aphrodisiac, morphologically,
# Nearest to construction: spherically, ecma, usaid, ilyich, kinsella, nigh, plasmids, monogatari,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5228 0.2053 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4760 0.2049 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4729 0.2042 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5104 0.2153 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5079 0.2157 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4724 0.2124 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4623 0.2126 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3992 0.2126 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4285 0.2087 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4487 0.2045 sec/batch
# Nearest to for: oiling, voluminous, batter, portman, filtered, encoded, logarithms, uneven,
# Nearest to nine: westport, frustrating, muse, four, top, jr, dramatist, zero,
# Nearest to years: female, population, gee, ppp, having, venetian, participated, fahd,
# Nearest to than: hibernation, spanning, covers, polling, rumsfeld, smallest, relay, take,
# Nearest to other: tenets, hermetic, influences, rdr, powering, ninlil, ildefonso, radiotherapy,
# Nearest to so: oxidising, avoids, classmates, suspect, receptors, experiencing, donoghue, you,
# Nearest to and: across, decades, translated, polarization, deluxe, mcgraw, objectives, filled,
# Nearest to at: sanity, centralist, gnaeus, swimmer, it, silk, disbanded, whalen,
# Nearest to frac: dynamic, z, transduction, topology, right, adequately, coughing, zapatistas,
# Nearest to placed: superfamilies, cloth, printer, just, agriculture, bamiyan, amnesty, cartels,
# Nearest to cost: indulgence, sills, appliance, antillean, turnout, converges, pleasures, refrigeration,
# Nearest to writers: syphilis, sweethearts, guessed, universalist, interregnum, algeciras, alistair, syriac,
# Nearest to test: perpetrated, hardens, serge, seis, flora, guesswork, std, seo,
# Nearest to animals: predetermined, skull, subshell, cheat, hardin, drawback, exemplary, bulwer,
# Nearest to joseph: william, reprint, greenlanders, watson, aphrodisiac, morphologically, ber, barrack,
# Nearest to construction: spherically, usaid, ecma, kinsella, ilyich, numbered, plasmids, plausibly,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4260 0.2088 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4201 0.2091 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4441 0.2123 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4081 0.2076 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4187 0.2080 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4589 0.2089 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3824 0.2092 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3983 0.2089 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4099 0.2110 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3681 0.2127 sec/batch
# Nearest to for: voluminous, oiling, batter, portman, filtered, encoded, password, lemelson,
# Nearest to nine: four, zero, jr, westport, dramatist, muse, scoreless, leslie,
# Nearest to years: female, ppp, population, male, participated, saboteur, fahd, having,
# Nearest to than: covers, hibernation, spanning, polling, rumsfeld, take, likely, smallest,
# Nearest to other: tenets, influences, hermetic, rdr, radiotherapy, powering, hypostatic, add,
# Nearest to so: avoids, oxidising, classmates, donoghue, suspect, secured, you, martyrs,
# Nearest to and: across, translated, groves, ameliorated, polarization, mcgraw, absorbed, casuistry,
# Nearest to at: sanity, centralist, gnaeus, ebb, it, swimmer, pierpont, insulating,
# Nearest to frac: z, right, transduction, q, sum, topology, vector, parameter,
# Nearest to placed: superfamilies, cloth, printer, just, verbose, cartels, saadia, bamiyan,
# Nearest to cost: indulgence, sills, appliance, antillean, converges, pleasures, generate, oort,
# Nearest to writers: syphilis, guessed, universalist, sweethearts, interregnum, alistair, syriac, algeciras,
# Nearest to test: hardens, perpetrated, flora, std, seo, guesswork, serge, seis,
# Nearest to animals: predetermined, skull, subshell, drawback, bulwer, screened, constellation, exemplary,
# Nearest to joseph: william, reprint, greenlanders, watson, aphrodisiac, publisher, abelard, obito,
# Nearest to construction: spherically, usaid, ecma, numbered, plasmids, metaphors, ilyich, plausibly,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3838 0.2131 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4069 0.2116 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3511 0.2102 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3556 0.2082 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3925 0.2055 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.4092 0.2075 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3990 0.2135 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3926 0.2058 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3359 0.2085 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3379 0.2062 sec/batch
# Nearest to for: encoded, batter, oiling, password, filtered, portman, voluminous, goods,
# Nearest to nine: zero, four, two, three, westport, muse, jr, leslie,
# Nearest to years: female, population, male, ppp, saboteur, having, participated, hawar,
# Nearest to than: covers, hibernation, polling, spanning, likely, take, pigment, subseteq,
# Nearest to other: influences, tenets, hypostatic, rdr, heavier, hermetic, unwillingness, ildefonso,
# Nearest to so: avoids, oxidising, secured, suspect, classmates, donoghue, idea, canute,
# Nearest to and: across, ameliorated, decades, polarization, groves, objectives, survived, friendship,
# Nearest to at: sanity, centralist, it, ebb, neuromancer, hdz, gnaeus, companies,
# Nearest to frac: z, q, right, transduction, sum, parameter, topology, pi,
# Nearest to placed: superfamilies, cloth, printer, just, verbose, cartels, damages, bamiyan,
# Nearest to cost: sills, indulgence, appliance, antillean, refrigeration, generate, pleasures, oort,
# Nearest to writers: syphilis, sweethearts, guessed, universalist, fictional, syriac, alistair, worlds,
# Nearest to test: hardens, perpetrated, serge, flora, std, refined, seo, guesswork,
# Nearest to animals: predetermined, skull, drawback, subshell, screened, grasses, bulwer, tarim,
# Nearest to joseph: william, reprint, greenlanders, watson, aphrodisiac, wissenschaften, verdun, obito,
# Nearest to construction: spherically, usaid, ilyich, ecma, indium, plasmids, plausibly, numbered,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3685 0.2091 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2672 0.2028 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3816 0.2057 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3604 0.2080 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3941 0.2070 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2917 0.2006 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3191 0.1998 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3399 0.2002 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2198 0.2010 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2939 0.2013 sec/batch
# Nearest to for: batter, password, vitali, encoded, oiling, filtered, voluminous, portman,
# Nearest to nine: zero, four, two, three, one, dramatist, jr, muse,
# Nearest to years: female, male, population, mortality, ppp, deaths, migrant, rate,
# Nearest to than: hibernation, covers, spanning, polling, take, likely, cautiously, rumsfeld,
# Nearest to other: influences, tenets, hypostatic, ildefonso, unwillingness, radiotherapy, hermetic, rat,
# Nearest to so: oxidising, avoids, secured, suspect, classmates, donoghue, you, idea,
# Nearest to and: ameliorated, across, mcgraw, decades, friendship, groves, exclave, polarization,
# Nearest to at: sanity, ebb, aino, centralist, neuromancer, hdz, whalen, companies,
# Nearest to frac: z, right, parameter, q, transduction, pi, vector, sum,
# Nearest to placed: superfamilies, cloth, printer, just, verbose, transposing, cartels, seldom,
# Nearest to cost: sills, refrigeration, generate, indulgence, appliance, antillean, oort, pleasures,
# Nearest to writers: syphilis, alistair, fictional, universalist, syriac, sweethearts, byrne, interregnum,
# Nearest to test: flora, hardens, refined, serge, std, guesswork, perpetrated, seo,
# Nearest to animals: skull, predetermined, subshell, drawback, grasses, eaten, bulwer, screened,
# Nearest to joseph: william, greenlanders, reprint, watson, wissenschaften, verdun, aphrodisiac, amphiphilic,
# Nearest to construction: spherically, usaid, ecma, ilyich, indium, plasmids, kinsella, monogatari,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3122 0.2023 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2777 0.2004 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3541 0.0885 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2529 0.2011 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2321 0.2012 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2405 0.2011 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1986 0.2004 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2112 0.2003 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2406 0.2008 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1564 0.2008 sec/batch
# Nearest to for: batter, oiling, password, vitali, voluminous, filtered, uneven, encoded,
# Nearest to nine: zero, four, one, two, three, muse, dramatist, jr,
# Nearest to years: female, male, population, mortality, migrant, deaths, rate, ppp,
# Nearest to than: covers, spanning, polling, hibernation, take, undeveloped, weigh, letterbox,
# Nearest to other: influences, tenets, rdr, ildefonso, hermetic, radiotherapy, unwillingness, uncompetitive,
# Nearest to so: oxidising, secured, avoids, classmates, suspect, you, idea, martyrs,
# Nearest to and: across, ameliorated, decades, jaipur, friendship, mcgraw, zimbabwe, biome,
# Nearest to at: centralist, ebb, aino, crewmen, sanity, bridgestone, benitez, ranch,
# Nearest to frac: z, right, q, transduction, parameter, pi, vector, sum,
# Nearest to placed: superfamilies, cloth, printer, just, verbose, transposing, hilly, bamiyan,
# Nearest to cost: sills, refrigeration, appliance, generate, antillean, indulgence, rulebase, converges,
# Nearest to writers: syphilis, fictional, syriac, universalist, alistair, sweethearts, worlds, byrne,
# Nearest to test: flora, hardens, serge, refined, std, guesswork, seo, seis,
# Nearest to animals: skull, grasses, eaten, subshell, roasted, insect, asteraceae, drawback,
# Nearest to joseph: william, reprint, greenlanders, watson, wissenschaften, verdun, obito, amphiphilic,
# Nearest to construction: spherically, usaid, ilyich, ecma, indium, flamsteed, kinsella, monogatari,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2444 0.2025 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2247 0.2002 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2381 0.2006 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1323 0.2003 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1865 0.2003 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1839 0.2004 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1465 0.2009 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1726 0.2006 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1848 0.2005 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1575 0.2004 sec/batch
# Nearest to for: batter, oiling, filtered, password, vitali, encoded, goods, declarations,
# Nearest to nine: zero, four, two, three, one, muse, scoreless, jr,
# Nearest to years: female, male, population, deaths, mortality, migrant, expectancy, rate,
# Nearest to than: covers, spanning, take, pigment, likely, undeveloped, hibernation, letterbox,
# Nearest to other: influences, tenets, rat, quite, uncompetitive, hermetic, radiotherapy, succinct,
# Nearest to so: secured, oxidising, you, avoids, suspect, classmates, conciliator, martyrs,
# Nearest to and: ameliorated, across, mcgraw, embossed, translated, casuistry, survived, ungodly,
# Nearest to at: crewmen, sanity, aino, benitez, ebb, leagues, centralist, okanagan,
# Nearest to frac: right, z, left, parameter, ldots, transduction, sum, pi,
# Nearest to placed: superfamilies, cloth, just, printer, verbose, transposing, bamiyan, hilly,
# Nearest to cost: sills, refrigeration, appliance, generate, indulgence, antillean, converges, marketable,
# Nearest to writers: fictional, syriac, universalist, alistair, syphilis, worlds, guessed, futhark,
# Nearest to test: flora, std, hardens, refined, serge, guesswork, seo, encapsulated,
# Nearest to animals: grasses, skull, eaten, roasted, subshell, asteraceae, insect, bulwer,
# Nearest to joseph: william, wissenschaften, reprint, greenlanders, amphiphilic, watson, obito, jodi,
# Nearest to construction: spherically, usaid, flamsteed, ilyich, ecma, indium, metaphors, kinsella,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1901 0.2019 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2124 0.2006 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1749 0.2009 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1886 0.2007 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1746 0.2009 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1770 0.2003 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1825 0.2015 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1794 0.2004 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1152 0.2014 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2083 0.2015 sec/batch
# Nearest to for: batter, password, vitali, oiling, goods, filtered, voluminous, coding,
# Nearest to nine: zero, two, one, four, three, muse, scoreless, eight,
# Nearest to years: female, male, population, migrant, expectancy, mortality, deaths, rate,
# Nearest to than: covers, likely, take, spanning, undeveloped, polling, letterbox, hibernation,
# Nearest to other: tenets, influences, quite, rat, succinct, hypostatic, unwillingness, radiotherapy,
# Nearest to so: you, secured, suspect, oxidising, donoghue, idea, avoids, classmates,
# Nearest to and: ameliorated, across, mcgraw, casuistry, deluxe, friendship, translated, zimbabwe,
# Nearest to at: ebb, crewmen, sanity, aino, okanagan, xs, leagues, bridgestone,
# Nearest to frac: right, z, left, then, pi, ldots, q, sum,
# Nearest to placed: superfamilies, cloth, just, printer, verbose, transposing, bamiyan, sentiment,
# Nearest to cost: sills, refrigeration, appliance, generate, indulgence, rulebase, money, converges,
# Nearest to writers: fictional, universalist, alistair, syphilis, syriac, futhark, novelists, writeups,
# Nearest to test: flora, std, serge, seo, guesswork, refined, hardens, paean,
# Nearest to animals: grasses, insect, skull, roasted, species, eaten, subshell, asteraceae,
# Nearest to joseph: william, wissenschaften, greenlanders, reprint, amphiphilic, obito, jodi, dhimmi,
# Nearest to construction: spherically, usaid, flamsteed, ilyich, metaphors, ecma, indium, nigh,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2122 0.2025 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1881 0.2014 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2013 0.2006 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1766 0.2009 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1510 0.2026 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1410 0.2012 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1485 0.2033 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1223 0.2017 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1969 0.2030 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2320 0.2036 sec/batch
# Nearest to for: voluminous, batter, password, vitali, woodward, maciej, contracts, shreveport,
# Nearest to nine: zero, one, two, four, three, muse, seven, eight,
# Nearest to years: female, male, population, migrant, expectancy, mortality, zero, deaths,
# Nearest to than: likely, polling, take, covers, spanning, rumsfeld, smallest, undeveloped,
# Nearest to other: influences, tenets, rat, unwillingness, succinct, buffet, aimee, cukor,
# Nearest to so: secured, you, suspect, idea, martyrs, conciliator, corky, canute,
# Nearest to and: friendship, ameliorated, mcgraw, survived, leadership, jaipur, decades, dissidents,
# Nearest to at: ebb, sanity, crewmen, whalen, youngest, okanagan, centralist, attended,
# Nearest to frac: right, z, pi, ldots, transduction, sum, refraction, mappings,
# Nearest to placed: superfamilies, cloth, just, printer, transposing, verbose, bamiyan, sentiment,
# Nearest to cost: refrigeration, sills, appliance, indulgence, generate, turnout, rulebase, priced,
# Nearest to writers: novelists, fictional, universalist, alistair, writeups, worlds, syphilis, futhark,
# Nearest to test: flora, std, encapsulated, refined, serge, seo, sextant, guesswork,
# Nearest to animals: grasses, insect, skull, teeth, roasted, species, asteraceae, gestation,
# Nearest to joseph: william, wissenschaften, reprint, amphiphilic, obito, greenlanders, jodi, abelard,
# Nearest to construction: spherically, flamsteed, usaid, ilyich, metaphors, untouchability, nigh, ecma,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2494 0.2150 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1289 0.2040 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1635 0.1998 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1499 0.2009 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0410 0.2004 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1463 0.2003 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1434 0.2014 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1373 0.2044 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1430 0.0337 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1394 0.2052 sec/batch
# Nearest to for: password, batter, vitali, contracts, coding, witcher, voluminous, woodward,
# Nearest to nine: one, zero, two, three, four, muse, eight, seven,
# Nearest to years: female, male, population, migrant, zero, mortality, expectancy, deaths,
# Nearest to than: likely, smallest, undeveloped, polling, weigh, covers, spanning, take,
# Nearest to other: influences, tenets, hypostatic, objectionable, quite, unwillingness, controversial, malayalam,
# Nearest to so: you, secured, suspect, conciliator, idea, oxidising, avoids, bicoid,
# Nearest to and: ameliorated, mcgraw, friendship, across, decades, jaipur, escarpment, based,
# Nearest to at: ebb, crewmen, okanagan, boston, leagues, whalen, sanity, aino,
# Nearest to frac: right, pi, left, mappings, coalitions, refraction, transduction, modulus,
# Nearest to placed: cloth, superfamilies, just, transposing, printer, verbose, sentiment, bamiyan,
# Nearest to cost: refrigeration, appliance, indulgence, sills, priced, generate, rulebase, converges,
# Nearest to writers: novelists, universalist, writeups, syphilis, alistair, futhark, fictional, worlds,
# Nearest to test: flora, std, serge, encapsulated, seo, refined, paean, multiplies,
# Nearest to animals: grasses, asteraceae, insect, species, roasted, skull, eaten, teeth,
# Nearest to joseph: william, wissenschaften, reprint, jodi, greenlanders, obito, deluise, amphiphilic,
# Nearest to construction: spherically, flamsteed, usaid, ilyich, metaphors, nigh, ecma, indium,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0856 0.2031 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0763 0.2045 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0937 0.2024 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0573 0.2017 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0836 0.2025 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0526 0.2029 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1054 0.2021 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1437 0.2034 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1191 0.2011 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0181 0.2018 sec/batch
# Nearest to for: batter, password, vitali, accommodate, coding, two, contracts, voluminous,
# Nearest to nine: zero, one, two, four, three, muse, eight, seven,
# Nearest to years: female, male, migrant, population, zero, year, expectancy, mortality,
# Nearest to than: undeveloped, likely, weigh, grenade, covers, smallest, take, mat,
# Nearest to other: influences, tenets, buffet, anatomical, rat, controversial, nucellus, objectionable,
# Nearest to so: secured, you, idea, oxidising, suspect, conciliator, martyrs, avoids,
# Nearest to and: the, across, of, survived, ameliorated, is, friendship, escarpment,
# Nearest to at: boston, ebb, okanagan, crewmen, nauvoo, timbered, crowned, womanhood,
# Nearest to frac: right, left, mappings, pi, modulus, dx, coalitions, refraction,
# Nearest to placed: cloth, superfamilies, just, printer, transposing, sentiment, bamiyan, verbose,
# Nearest to cost: refrigeration, indulgence, priced, generate, sills, appliance, marketable, pleasures,
# Nearest to writers: novelists, universalist, futhark, alistair, writeups, worlds, guessed, syphilis,
# Nearest to test: flora, serge, streak, std, seis, paean, encapsulated, seo,
# Nearest to animals: grasses, asteraceae, insect, teeth, species, skull, exemplary, reproductive,
# Nearest to joseph: william, wissenschaften, reprint, jodi, amphiphilic, greenlanders, columnists, deluise,
# Nearest to construction: spherically, usaid, flamsteed, ilyich, metaphors, indium, nigh, untouchability,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0270 0.2038 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0170 0.2024 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0135 0.2021 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0434 0.2011 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0645 0.2020 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0437 0.2095 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0648 0.2094 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1069 0.2045 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0772 0.2004 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0557 0.2032 sec/batch
# Nearest to for: batter, vitali, password, logarithms, cumulant, two, contracts, accommodate,
# Nearest to nine: zero, one, two, four, three, seven, eight, muse,
# Nearest to years: female, male, zero, migrant, population, expectancy, year, mortality,
# Nearest to than: take, likely, weigh, grenade, undeveloped, smallest, polling, cautiously,
# Nearest to other: tenets, rat, influences, buffet, nucellus, quite, controversial, anatomical,
# Nearest to so: you, oxidising, secured, conciliator, suspect, corky, vibration, idea,
# Nearest to and: the, is, ungodly, across, friendship, of, mcgraw, ameliorated,
# Nearest to at: ebb, okanagan, xs, boston, attended, sanity, interred, know,
# Nearest to frac: right, left, then, coalitions, refraction, pi, modulus, yau,
# Nearest to placed: cloth, superfamilies, printer, just, transposing, verbose, sentiment, bamiyan,
# Nearest to cost: priced, generate, sills, refrigeration, indulgence, appliance, marketable, converges,
# Nearest to writers: novelists, futhark, writeups, alistair, universalist, among, guessed, worlds,
# Nearest to test: flora, std, manifested, serge, warnings, encapsulated, seo, refined,
# Nearest to animals: grasses, asteraceae, insect, teeth, species, reproductive, marine, bulwer,
# Nearest to joseph: william, wissenschaften, jodi, amphiphilic, reprint, workload, columnists, treating,
# Nearest to construction: spherically, ilyich, usaid, flamsteed, metaphors, untouchability, indium, numbered,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0388 0.2059 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1331 0.2047 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0757 0.2025 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0494 0.2020 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0587 0.2016 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0603 0.2006 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0718 0.2011 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0399 0.2036 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0707 0.2018 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0672 0.2055 sec/batch
# Nearest to for: batter, two, vitali, password, cumulant, contracts, logarithms, urges,
# Nearest to nine: one, zero, two, three, four, eight, seven, muse,
# Nearest to years: female, male, zero, migrant, year, population, expectancy, deaths,
# Nearest to than: take, polling, likely, weigh, smallest, undeveloped, grenade, pigment,
# Nearest to other: tenets, rat, influences, nucellus, quite, petty, objectionable, buffet,
# Nearest to so: you, secured, conciliator, suspect, oxidising, idea, cranmer, corky,
# Nearest to and: the, survived, ameliorated, of, leadership, exclave, across, friendship,
# Nearest to at: ebb, interred, council, hdz, attended, timbered, youngest, took,
# Nearest to frac: right, left, modulus, coalitions, refraction, then, pi, yau,
# Nearest to placed: cloth, superfamilies, printer, just, transposing, verbose, sentiment, bamiyan,
# Nearest to cost: priced, sills, refrigeration, generate, indulgence, appliance, marketable, rulebase,
# Nearest to writers: novelists, writeups, futhark, alistair, universalist, literary, swaim, worlds,
# Nearest to test: flora, serge, std, seo, warnings, manifested, encapsulated, streak,
# Nearest to animals: grasses, asteraceae, insect, teeth, species, marine, bulwer, reproductive,
# Nearest to joseph: william, wissenschaften, jodi, reprint, amphiphilic, workload, columnists, greenlanders,
# Nearest to construction: spherically, ilyich, flamsteed, usaid, metaphors, untouchability, numbered, towns,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0409 0.2089 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0216 0.2041 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0442 0.2038 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0628 0.2040 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0828 0.2041 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0910 0.2024 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1127 0.2027 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0620 0.2046 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0417 0.2026 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0586 0.2021 sec/batch
# Nearest to for: batter, two, password, contracts, urges, witcher, notify, vitali,
# Nearest to nine: one, zero, two, three, four, seven, eight, muse,
# Nearest to years: female, male, zero, migrant, population, year, expectancy, fertility,
# Nearest to than: polling, take, weigh, smallest, cautiously, likely, higher, rumsfeld,
# Nearest to other: rat, tenets, influences, quite, nucellus, hypostatic, most, transoxiana,
# Nearest to so: you, secured, conciliator, idea, oxidising, suspect, corky, martyrs,
# Nearest to and: the, ameliorated, in, of, is, exclave, survived, across,
# Nearest to at: ebb, interred, okanagan, attended, boston, hdz, youngest, timbered,
# Nearest to frac: right, left, coalitions, modulus, refraction, then, pi, yau,
# Nearest to placed: cloth, printer, superfamilies, transposing, just, verbose, sentiment, ammoniac,
# Nearest to cost: priced, sills, refrigeration, generate, indulgence, appliance, rulebase, marketable,
# Nearest to writers: novelists, writeups, swaim, futhark, alistair, among, literary, universalist,
# Nearest to test: flora, warnings, handley, serge, std, encapsulated, ibf, seo,
# Nearest to animals: grasses, asteraceae, insect, species, teeth, bulwer, reproductive, marine,
# Nearest to joseph: william, wissenschaften, reprint, amphiphilic, workload, jodi, bertold, greenlanders,
# Nearest to construction: spherically, usaid, flamsteed, ilyich, metaphors, untouchability, nigh, towns,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0043 0.2042 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0264 0.2035 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0737 0.2008 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0275 0.2003 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0834 0.2004 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0550 0.1774 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9852 0.2011 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9714 0.2007 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0061 0.2005 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9910 0.2007 sec/batch
# Nearest to for: batter, urges, password, caching, contracts, firefight, cumulant, notify,
# Nearest to nine: one, zero, two, three, four, eight, seven, five,
# Nearest to years: female, male, year, zero, migrant, population, fertility, expectancy,
# Nearest to than: cautiously, polling, likely, take, grenade, weigh, pigment, calamine,
# Nearest to other: tenets, nucellus, quite, rat, influences, most, hypostatic, within,
# Nearest to so: you, secured, suspect, conciliator, idea, oxidising, laugh, corky,
# Nearest to and: the, in, survived, ameliorated, is, friendship, passau, translated,
# Nearest to at: ebb, interred, attended, boston, the, in, council, okanagan,
# Nearest to frac: right, left, modulus, coalitions, refraction, transduction, yau, pi,
# Nearest to placed: cloth, transposing, just, superfamilies, printer, verbose, sentiment, swore,
# Nearest to cost: priced, sills, generate, refrigeration, marketable, indulgence, appliance, rulebase,
# Nearest to writers: novelists, writeups, futhark, swaim, alistair, literary, among, universalist,
# Nearest to test: flora, handley, serge, warnings, std, streak, encapsulated, ibf,
# Nearest to animals: grasses, asteraceae, insect, marine, species, reproductive, teeth, bulwer,
# Nearest to joseph: william, wissenschaften, columnists, reprint, jodi, workload, deluise, keter,
# Nearest to construction: spherically, usaid, flamsteed, ilyich, machinery, metaphors, indium, chau,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9764 0.2023 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9657 0.2003 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0231 0.2001 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0276 0.2002 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0144 0.2002 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0070 0.2005 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9265 0.2005 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9721 0.2004 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9415 0.1999 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9660 0.2002 sec/batch
# Nearest to for: batter, two, contracts, urges, password, caching, witcher, cumulant,
# Nearest to nine: one, zero, two, four, three, seven, eight, five,
# Nearest to years: female, male, year, zero, migrant, population, expectancy, deaths,
# Nearest to than: cautiously, take, weigh, likely, grenade, calamine, higher, polling,
# Nearest to other: tenets, quite, nucellus, rat, most, influences, within, as,
# Nearest to so: oxidising, secured, you, conciliator, idea, suspect, tell, cranmer,
# Nearest to and: the, is, in, of, survived, ameliorated, has, escarpment,
# Nearest to at: ebb, boston, attended, interred, okanagan, the, took, timbered,
# Nearest to frac: right, left, modulus, coalitions, transduction, then, refraction, pi,
# Nearest to placed: cloth, printer, just, transposing, superfamilies, verbose, dock, swore,
# Nearest to cost: priced, sills, generate, refrigeration, marketable, indulgence, appliance, converges,
# Nearest to writers: novelists, writeups, futhark, swaim, alistair, among, literary, universalist,
# Nearest to test: flora, std, streak, handley, ibf, serge, warnings, encapsulated,
# Nearest to animals: grasses, asteraceae, marine, insect, reproductive, species, bulwer, teeth,
# Nearest to joseph: william, wissenschaften, amphiphilic, jodi, workload, reprint, columnists, aclu,
# Nearest to construction: spherically, usaid, ilyich, flamsteed, metaphors, machinery, indium, numbered,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9864 0.2022 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0201 0.2003 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9617 0.2000 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0345 0.1999 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0315 0.2002 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9447 0.2002 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0100 0.2004 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0055 0.2003 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9772 0.2006 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0005 0.2000 sec/batch
# Nearest to for: two, batter, witcher, password, cumulant, contracts, urges, vitali,
# Nearest to nine: one, zero, two, four, three, eight, seven, five,
# Nearest to years: female, male, year, zero, migrant, expectancy, population, deaths,
# Nearest to than: take, likely, calamine, polling, higher, cautiously, topspinner, grenade,
# Nearest to other: tenets, nucellus, rat, hypostatic, quite, objectionable, succinct, cryptozoologists,
# Nearest to so: you, conciliator, secured, idea, oxidising, suspect, vibration, corky,
# Nearest to and: the, in, of, is, leadership, mcgraw, has, an,
# Nearest to at: interred, ebb, attended, the, boston, council, took, okanagan,
# Nearest to frac: right, left, modulus, coalitions, refraction, transduction, pi, yau,
# Nearest to placed: cloth, printer, just, transposing, superfamilies, verbose, swore, decorum,
# Nearest to cost: priced, generate, sills, marketable, refrigeration, converges, indulgence, investments,
# Nearest to writers: novelists, writeups, futhark, swaim, among, literary, fiction, alistair,
# Nearest to test: flora, warnings, std, serge, ibf, needless, encapsulated, streak,
# Nearest to animals: grasses, marine, asteraceae, insect, bulwer, reproductive, species, teeth,
# Nearest to joseph: william, wissenschaften, jodi, amphiphilic, workload, columnists, obito, aclu,
# Nearest to construction: spherically, ilyich, metaphors, usaid, flamsteed, numbered, presented, handguard,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0157 0.2026 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9781 0.2003 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0056 0.2002 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0152 0.2005 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0145 0.2006 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0056 0.2004 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9816 0.2002 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9658 0.2002 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9874 0.1995 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0353 0.2006 sec/batch
# Nearest to for: two, batter, password, urges, cumulant, caching, contracts, degraded,
# Nearest to nine: one, zero, two, three, four, seven, eight, five,
# Nearest to years: female, zero, year, male, migrant, population, expectancy, deaths,
# Nearest to than: higher, polling, cautiously, likely, calamine, take, undecided, weigh,
# Nearest to other: most, quite, tenets, their, hypostatic, nucellus, in, petty,
# Nearest to so: you, secured, conciliator, oxidising, idea, tell, suspect, cranmer,
# Nearest to and: the, of, in, is, to, has, leadership, ameliorated,
# Nearest to at: attended, ebb, interred, boston, hdz, the, health, took,
# Nearest to frac: right, left, coalitions, modulus, pi, refraction, transduction, borrelly,
# Nearest to placed: cloth, just, printer, superfamilies, transposing, verbose, dock, eerie,
# Nearest to cost: generate, sills, priced, indulgence, converges, refrigeration, appliance, investments,
# Nearest to writers: novelists, writeups, swaim, literary, futhark, fiction, among, centenarians,
# Nearest to test: flora, ibf, warnings, std, genet, serge, handley, encapsulated,
# Nearest to animals: grasses, asteraceae, marine, insect, teeth, bulwer, reproductive, exemplary,
# Nearest to joseph: william, wissenschaften, jodi, amphiphilic, workload, reprint, columnists, obito,
# Nearest to construction: spherically, ilyich, metaphors, flamsteed, towns, usaid, excavations, silting,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9562 0.2024 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1068 0.2001 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0275 0.1997 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0649 0.1997 sec/batch
# ...
# Nearest to joseph: meaning, narcissus, symbolic, ishmael, poole, aclu, jodi, sanderson,
# Nearest to construction: metaphors, ilyich, riders, numbered, wholes, silting, quay, sawmills,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8783 0.2017 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7802 0.1999 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8535 0.2001 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7885 0.1994 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8036 0.1996 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8333 0.1999 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8745 0.1997 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8290 0.1998 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8671 0.1995 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9508 0.1999 sec/batch
# Nearest to for: the, and, in, a, as, is, two, has,
# Nearest to nine: one, two, zero, four, three, eight, seven, six,
# Nearest to years: zero, year, over, male, female, migrant, four, three,
# Nearest to than: less, zero, more, higher, lifes, about, faster, much,
# Nearest to other: such, of, and, as, most, in, their, the,
# Nearest to so: bekaa, cranmer, tell, into, like, the, again, to,
# Nearest to and: the, of, in, is, as, by, for, with,
# Nearest to at: in, the, after, and, zero, this, a, first,
# Nearest to frac: right, tempted, strasse, modulus, left, chronica, cleaves, approximates,
# Nearest to placed: printer, dock, just, cloth, transposing, decorum, below, eerie,
# Nearest to cost: priced, shrinking, investments, costs, turnout, expensive, indulgence, mildred,
# Nearest to writers: novelists, literary, fiction, journalists, writeups, novel, autodidacts, swaim,
# Nearest to test: odi, ibf, testing, warnings, champion, std, follows, quantico,
# Nearest to animals: bulwer, exemplary, behaviors, asteraceae, marine, evolved, feral, iblis,
# Nearest to joseph: meaning, jodi, aclu, symbolic, narcissus, poole, ishmael, sanderson,
# Nearest to construction: metaphors, ilyich, wholes, numbered, harpsichord, riders, silting, spherically,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8132 0.2017 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8599 0.1999 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8472 0.1998 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8415 0.2006 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8514 0.1996 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8730 0.1999 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8384 0.2000 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8278 0.1996 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8799 0.1999 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8643 0.2003 sec/batch
# Nearest to for: the, and, as, in, has, of, a, two,
# Nearest to nine: one, two, three, zero, eight, seven, four, five,
# Nearest to years: zero, year, over, male, female, migrant, six, four,
# Nearest to than: less, zero, lifes, higher, about, more, although, seven,
# Nearest to other: and, most, such, of, as, in, their, is,
# Nearest to so: cranmer, bekaa, to, tell, into, not, again, like,
# Nearest to and: the, of, in, as, is, for, with, by,
# Nearest to at: the, in, after, zero, and, of, this, rate,
# Nearest to frac: right, tempted, strasse, modulus, chronica, left, cleaves, approximates,
# Nearest to placed: printer, dock, just, cloth, transposing, decorum, ddrmax, eerie,
# Nearest to cost: priced, shrinking, turnout, costs, min, generate, investments, rhee,
# Nearest to writers: novelists, fiction, literary, journalists, autodidacts, writeups, novel, swaim,
# Nearest to test: odi, ibf, testing, champion, warnings, quantico, licenses, nitrox,
# Nearest to animals: exemplary, bulwer, feral, asteraceae, behaviors, marine, reformed, evolved,
# Nearest to joseph: ishmael, jodi, poole, aclu, symbolic, narcissus, meaning, wissenschaften,
# Nearest to construction: metaphors, ilyich, wholes, numbered, riders, silting, excavations, harpsichord,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8611 0.2018 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8723 0.2001 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8345 0.2001 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8482 0.1995 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8745 0.2002 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8194 0.2004 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9635 0.2005 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9042 0.1999 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9199 0.1996 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8278 0.2000 sec/batch
# Nearest to for: the, and, a, as, two, of, has, in,
# Nearest to nine: one, two, three, zero, four, seven, eight, five,
# Nearest to years: zero, year, male, over, female, population, migrant, three,
# Nearest to than: less, zero, more, lifes, about, higher, faster, five,
# Nearest to other: such, most, and, of, as, in, is, their,
# Nearest to so: bekaa, to, cranmer, the, tell, astray, not, give,
# Nearest to and: the, of, in, as, by, to, with, is,
# Nearest to at: in, the, after, and, zero, rate, this, of,
# Nearest to frac: right, tempted, strasse, modulus, chronica, left, cleaves, coalitions,
# Nearest to placed: printer, just, dock, transposing, eerie, below, cloth, decorum,
# Nearest to cost: priced, turnout, shrinking, rhee, generate, indulgence, costs, min,
# Nearest to writers: novelists, fiction, literary, autodidacts, journalists, dramatists, writeups, swaim,
# Nearest to test: odi, ibf, testing, warnings, champion, licenses, genet, std,
# Nearest to animals: exemplary, bulwer, feral, behaviors, reformed, outlays, marine, iblis,
# Nearest to joseph: ishmael, jodi, narcissus, poole, latter, aclu, symbolic, sanderson,
# Nearest to construction: metaphors, ilyich, wholes, silting, riders, excavations, numbered, structural,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8120 0.2011 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.9035 0.1998 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7895 0.2000 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8653 0.2002 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8651 0.1999 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8551 0.1997 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9159 0.0964 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8133 0.1999 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8380 0.2002 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8154 0.2004 sec/batch
# Nearest to for: the, and, a, in, as, of, has, is,
# Nearest to nine: one, two, three, eight, zero, four, seven, six,
# Nearest to years: zero, year, male, over, female, migrant, population, three,
# Nearest to than: less, lifes, about, zero, more, higher, faster, though,
# Nearest to other: such, most, and, as, of, is, their, are,
# Nearest to so: bekaa, cranmer, tell, to, like, is, not, wasn,
# Nearest to and: the, of, in, by, as, is, with, for,
# Nearest to at: in, the, after, zero, of, and, a, years,
# Nearest to frac: right, tempted, strasse, modulus, chronica, left, coalitions, cleaves,
# Nearest to placed: printer, dock, transposing, just, cloth, eerie, below, oscars,
# Nearest to cost: priced, shrinking, turnout, indulgence, expensive, costs, investments, converges,
# Nearest to writers: novelists, literary, fiction, journalists, autodidacts, dramatists, centenarians, writeups,
# Nearest to test: odi, ibf, testing, champion, warnings, quantico, handley, tests,
# Nearest to animals: bulwer, exemplary, asteraceae, feral, marine, iblis, behaviors, moose,
# Nearest to joseph: ishmael, poole, sanderson, meaning, latter, narcissus, insomnia, jodi,
# Nearest to construction: metaphors, ilyich, wholes, riders, numbered, excavations, quay, silting,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8220 0.2017 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8110 0.1998 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8263 0.1998 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7928 0.1999 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8497 0.1997 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8244 0.1999 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8623 0.1998 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7646 0.2001 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8166 0.1998 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8025 0.1999 sec/batch
# Nearest to for: the, and, in, a, of, is, has, as,
# Nearest to nine: one, two, three, four, zero, eight, seven, six,
# Nearest to years: zero, year, over, male, female, population, four, migrant,
# Nearest to than: less, more, zero, lifes, though, about, although, five,
# Nearest to other: and, of, such, as, most, in, is, the,
# Nearest to so: to, cranmer, bekaa, like, tell, is, into, do,
# Nearest to and: the, of, in, by, is, for, as, with,
# Nearest to at: the, in, after, zero, this, and, of, rate,
# Nearest to frac: right, tempted, modulus, strasse, left, chronica, cleaves, labatt,
# Nearest to placed: printer, dock, just, transposing, eerie, below, cloth, oscars,
# Nearest to cost: priced, turnout, indulgence, costs, expensive, shrinking, min, incipit,
# Nearest to writers: novelists, fiction, literary, journalists, autodidacts, writeups, dramatists, centenarians,
# Nearest to test: odi, ibf, testing, champion, warnings, follows, quantico, innings,
# Nearest to animals: bulwer, exemplary, behaviors, reformed, asteraceae, marine, feral, iblis,
# Nearest to joseph: latter, meaning, ishmael, narcissus, symbolic, aclu, poole, sanderson,
# Nearest to construction: metaphors, numbered, riders, ilyich, wholes, excavations, structural, built,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7552 0.2011 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8236 0.1998 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8530 0.2002 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8373 0.1996 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8275 0.1998 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8953 0.1998 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8521 0.2001 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8048 0.1995 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8295 0.1997 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8288 0.2000 sec/batch
# Nearest to for: and, the, in, a, of, is, has, as,
# Nearest to nine: one, two, three, eight, zero, four, seven, six,
# Nearest to years: zero, over, year, male, female, four, six, one,
# Nearest to than: less, zero, more, about, lifes, although, are, though,
# Nearest to other: and, of, such, as, most, in, is, are,
# Nearest to so: cranmer, bekaa, to, like, give, tell, is, again,
# Nearest to and: the, of, in, for, by, is, as, with,
# Nearest to at: the, in, after, of, and, this, zero, a,
# Nearest to frac: right, tempted, strasse, modulus, left, chronica, cleaves, coalitions,
# Nearest to placed: printer, dock, transposing, just, below, eerie, cloth, oscars,
# Nearest to cost: priced, costs, expensive, investments, turnout, shrinking, indulgence, min,
# Nearest to writers: novelists, fiction, literary, journalists, autodidacts, writeups, dramatists, centenarians,
# Nearest to test: odi, testing, ibf, warnings, follows, champion, nitrox, genet,
# Nearest to animals: bulwer, exemplary, asteraceae, feral, reformed, marine, behaviors, savannas,
# Nearest to joseph: meaning, latter, poole, ishmael, jodi, symbolic, aclu, sanderson,
# Nearest to construction: metaphors, ilyich, numbered, riders, wholes, harpsichord, structural, aesthetic,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8575 0.2018 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8310 0.1995 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8411 0.2000 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8637 0.1997 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8634 0.1997 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8452 0.2005 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8289 0.1997 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8562 0.2003 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8134 0.2002 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8090 0.1995 sec/batch
# Nearest to for: and, the, a, of, in, as, two, be,
# Nearest to nine: one, two, three, seven, eight, four, zero, five,
# Nearest to years: zero, year, over, male, six, four, female, one,
# Nearest to than: less, zero, more, five, lifes, about, although, though,
# Nearest to other: and, of, such, most, as, are, in, their,
# Nearest to so: to, cranmer, bekaa, the, tell, give, like, is,
# Nearest to and: the, of, in, by, for, with, as, is,
# Nearest to at: the, in, and, after, of, this, zero, a,
# Nearest to frac: right, tempted, strasse, modulus, chronica, cleaves, left, sympathy,
# Nearest to placed: printer, transposing, dock, just, below, gow, decorum, eerie,
# Nearest to cost: priced, expensive, turnout, costs, investments, shrinking, indulgence, rhee,
# Nearest to writers: novelists, literary, fiction, journalists, writeups, autodidacts, dramatists, swaim,
# Nearest to test: odi, testing, ibf, champion, warnings, tests, nitrox, genet,
# Nearest to animals: feral, bulwer, exemplary, asteraceae, reformed, outlays, marine, satsuki,
# Nearest to joseph: ishmael, poole, narcissus, symbolic, jodi, meaning, sanderson, moveable,
# Nearest to construction: metaphors, numbered, ilyich, excavations, wholes, riders, silting, quay,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8669 0.2018 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7951 0.2006 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9046 0.2004 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8988 0.2000 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8977 0.1994 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8397 0.2002 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8075 0.1994 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8366 0.1993 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7152 0.2000 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8435 0.2002 sec/batch
# Nearest to for: and, the, a, as, in, also, is, has,
# Nearest to nine: one, three, two, eight, seven, zero, four, six,
# Nearest to years: zero, over, year, male, female, three, population, six,
# Nearest to than: less, more, zero, about, lifes, although, five, higher,
# Nearest to other: and, such, most, as, of, in, are, their,
# Nearest to so: to, cranmer, tell, bekaa, like, give, do, come,
# Nearest to and: the, of, in, by, is, for, as, with,
# Nearest to at: in, the, after, and, zero, rate, this, of,
# Nearest to frac: tempted, right, strasse, modulus, chronica, cleaves, coalitions, approximates,
# Nearest to placed: printer, transposing, dock, just, below, oscars, eerie, gow,
# Nearest to cost: priced, expensive, costs, investments, turnout, converges, indulgence, shrinking,
# Nearest to writers: novelists, literary, fiction, journalists, autodidacts, writeups, dramatists, swaim,
# Nearest to test: odi, testing, ibf, tests, champion, warnings, genet, quantico,
# Nearest to animals: bulwer, feral, exemplary, asteraceae, reformed, satsuki, carnivores, behaviors,
# Nearest to joseph: ishmael, latter, narcissus, poole, jodi, meaning, symbolic, sanderson,
# Nearest to construction: metaphors, numbered, ilyich, wholes, excavations, structural, aluminum, quay,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8386 0.2015 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8280 0.2000 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
